# %% [markdown]
# # Thư viện

# %%
import pandas as pd
import os
from random import randint
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# # Dictionary cho nhãn

# %%
labels_dict = {'Basophil': 0, 'Eosinophil': 1, 'Lymphocyte': 2, 'Monocyte': 3, 'Neutrophil': 4}
classes = list(labels_dict.keys())

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.applications.inception_v3 import InceptionV3
from keras.layers import Input, Dropout, Dense, GlobalAveragePooling2D, BatchNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.models import Model
from tensorflow.keras import regularizers
from keras.initializers import glorot_uniform
from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# # Cấu hình tham số cơ bản

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 299

# %% [markdown]
# # Tạo ImageDataGenerator

# %%
data_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,         # Thêm xoay ảnh ngẫu nhiên trong khoảng ±20 độ
    width_shift_range=0.1,     # Tăng range shift lên 0.1
    height_shift_range=0.1,    # Tăng range shift lên 0.1
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.2,          # Thêm zoom ngẫu nhiên ±15%
    shear_range=0.2,         # Thêm biến dạng hình ảnh
    brightness_range=[0.8, 1.2],  # Thêm điều chỉnh độ sáng
    fill_mode='nearest',       # Xử lý pixels mới sau khi biến đổi
    validation_split=0.3,
    channel_shift_range=50.0
)

# %% [markdown]
# # Khởi tạo dữ liệu training và validation

# %%
train_data = data_gen.flow_from_directory(
    directory='Train',
    subset='training',
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode='categorical',
    target_size=(IMAGE_SIZE, IMAGE_SIZE)
)

valid_data = data_gen.flow_from_directory(
    directory='Train',
    subset='validation',
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode='categorical',
    target_size=(IMAGE_SIZE, IMAGE_SIZE)
)
# Out:
# Found 7124 images belonging to 5 classes.
# Found 3051 images belonging to 5 classes.

# %% [markdown]
# # Dữ liệu test

# %%
test_data = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory='Test',
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode='categorical',
    target_size=(IMAGE_SIZE, IMAGE_SIZE)
)
# Out:
# Found 4339 images belonging to 5 classes.

# %% [markdown]
# # Hiển thị ảnh mẫu

# %%
image, label = next(train_data)
plt.figure(figsize=(12, 12))
for i in range(12):
    plt.subplot(4, 4, i+1)
    plt.imshow(image[i])
    plt.title(classes[np.argmax(label[i])])
    plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8509804..0.92156863].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9843137..0.5294118].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.75686276..0.5294118].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9764706..0.73333335].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7176471..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9607843..0.54509807].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4980392..0.99215686].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.99215686..0.22352946].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.92941177..0.36470592].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.96862745..0.6].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.84313726..0.45098042].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.94509804..0.4901961].

# %% [markdown]
# # Tính class weights

# %%
classes_array = train_data.classes
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(classes_array),
    y=classes_array
)
class_weight_dict = dict(enumerate(class_weights))

# %% [markdown]
# # Tạo generator tùy chỉnh

# %%
def custom_data_generator(data_gen, class_weight_dict):
    while True:
        X_batch, y_batch = next(data_gen)
        sample_weights = np.array([class_weight_dict[np.argmax(label)] for label in y_batch])
        yield X_batch, y_batch, sample_weights

train_data_gen = custom_data_generator(train_data, class_weight_dict)

# %% [markdown]
# # Khởi tạo mô hình với InceptionV3

# %%
net = InceptionV3(include_top=False, weights='imagenet', input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
net.trainable = False

# %% [markdown]
# # Thêm các lớp phía trên

# %%
x = net.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.0005))(x)
x = Dropout(0.5)(x)
x = Dense(5, activation='softmax',
          kernel_initializer=glorot_uniform(),
          kernel_regularizer=regularizers.l2(0.001))(x)

# %% [markdown]
# # Kết nối lại mô hình

# %%
model = Model(inputs=net.input, outputs=x)

# %% [markdown]
# # Cấu hình optimizer và compile mô hình

# %%
adam = tf.keras.optimizers.Adam(learning_rate=2e-4)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Callback cho training

# %%
ES = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=8, mode='min', restore_best_weights=True, verbose=1)
RL = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, verbose=1, mode='min', min_lr=1e-7)
callbacks = [ES, RL]

# %% [markdown]
# # Huấn luyện lần 1

# %%
steps_per_epoch = np.ceil(len(train_data.filenames) / BATCH_SIZE).astype(int)
validation_steps = np.ceil(len(valid_data.filenames) / BATCH_SIZE).astype(int)

history1 = model.fit(
    train_data_gen,
    validation_data=valid_data,
    epochs=50,  # Số epochs cho giai đoạn 1
    callbacks=callbacks,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps
)
# Out:
# Epoch 1/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4336 - loss: 1.6878
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 523s 2s/step - accuracy: 0.4343 - loss: 1.6860 - val_accuracy: 0.7342 - val_loss: 0.9862 - learning_rate: 2.0000e-04
# Epoch 2/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 473s 2s/step - accuracy: 0.7624 - loss: 0.8457 - val_accuracy: 0.7388 - val_loss: 1.0097 - learning_rate: 2.0000e-04
# Epoch 3/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 480s 2s/step - accuracy: 0.7923 - loss: 0.7718 - val_accuracy: 0.7493 - val_loss: 0.9920 - learning_rate: 2.0000e-04
# Epoch 4/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 526s 2s/step - accuracy: 0.8235 - loss: 0.6762 - val_accuracy: 0.7434 - val_loss: 1.0261 - learning_rate: 2.0000e-04
# Epoch 5/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 482s 2s/step - accuracy: 0.8292 - loss: 0.6368 - val_accuracy: 0.7778 - val_loss: 0.9260 - learning_rate: 2.0000e-04
# Epoch 6/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 473s 2s/step - accuracy: 0.8551 - loss: 0.6215 - val_accuracy: 0.7856 - val_loss: 0.9147 - learning_rate: 2.0000e-04
# Epoch 7/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.8524 - loss: 0.5929 - val_accuracy: 0.7761 - val_loss: 0.9429 - learning_rate: 2.0000e-04
# Epoch 8/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 456s 2s/step - accuracy: 0.8576 - loss: 0.5782 - val_accuracy: 0.7889 - val_loss: 0.8880 - learning_rate: 2.0000e-04
# Epoch 9/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 451s 2s/step - accuracy: 0.8519 - loss: 0.5774 - val_accuracy: 0.7955 - val_loss: 0.8652 - learning_rate: 2.0000e-04
# Epoch 10/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 452s 2s/step - accuracy: 0.8621 - loss: 0.5646 - val_accuracy: 0.7794 - val_loss: 0.9054 - learning_rate: 2.0000e-04
# Epoch 11/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 450s 2s/step - accuracy: 0.8614 - loss: 0.5525 - val_accuracy: 0.7965 - val_loss: 0.8457 - learning_rate: 2.0000e-04
# Epoch 12/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 477s 2s/step - accuracy: 0.8661 - loss: 0.5643 - val_accuracy: 0.8197 - val_loss: 0.8095 - learning_rate: 2.0000e-04
# Epoch 13/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 483s 2s/step - accuracy: 0.8743 - loss: 0.5346 - val_accuracy: 0.8010 - val_loss: 0.8386 - learning_rate: 2.0000e-04
# Epoch 14/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 478s 2s/step - accuracy: 0.8734 - loss: 0.5129 - val_accuracy: 0.7693 - val_loss: 0.9824 - learning_rate: 2.0000e-04
# Epoch 15/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 711s 3s/step - accuracy: 0.8875 - loss: 0.4746 - val_accuracy: 0.7879 - val_loss: 0.8687 - learning_rate: 2.0000e-04
# Epoch 16/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8923 - loss: 0.4732
# Epoch 16: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 747s 3s/step - accuracy: 0.8923 - loss: 0.4732 - val_accuracy: 0.8083 - val_loss: 0.8482 - learning_rate: 2.0000e-04
# Epoch 17/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 728s 3s/step - accuracy: 0.9014 - loss: 0.4642 - val_accuracy: 0.8060 - val_loss: 0.8227 - learning_rate: 1.0000e-04
# Epoch 18/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 731s 3s/step - accuracy: 0.9031 - loss: 0.4346 - val_accuracy: 0.8056 - val_loss: 0.8216 - learning_rate: 1.0000e-04
# Epoch 19/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 716s 3s/step - accuracy: 0.9050 - loss: 0.4484 - val_accuracy: 0.7994 - val_loss: 0.8683 - learning_rate: 1.0000e-04
# Epoch 20/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 732s 3s/step - accuracy: 0.8944 - loss: 0.4481 - val_accuracy: 0.8174 - val_loss: 0.8080 - learning_rate: 1.0000e-04
# Epoch 21/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 741s 3s/step - accuracy: 0.9000 - loss: 0.4699 - val_accuracy: 0.8086 - val_loss: 0.8344 - learning_rate: 1.0000e-04
# Epoch 22/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 722s 3s/step - accuracy: 0.9099 - loss: 0.4290 - val_accuracy: 0.8299 - val_loss: 0.7639 - learning_rate: 1.0000e-04
# Epoch 23/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 720s 3s/step - accuracy: 0.9014 - loss: 0.4188 - val_accuracy: 0.8237 - val_loss: 0.7573 - learning_rate: 1.0000e-04
# Epoch 24/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 725s 3s/step - accuracy: 0.9121 - loss: 0.4195 - val_accuracy: 0.8178 - val_loss: 0.7629 - learning_rate: 1.0000e-04
# Epoch 25/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 789s 4s/step - accuracy: 0.9074 - loss: 0.4401 - val_accuracy: 0.8292 - val_loss: 0.7476 - learning_rate: 1.0000e-04
# Epoch 26/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 794s 4s/step - accuracy: 0.9068 - loss: 0.4302 - val_accuracy: 0.8109 - val_loss: 0.7744 - learning_rate: 1.0000e-04
# Epoch 27/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 792s 4s/step - accuracy: 0.9035 - loss: 0.4213 - val_accuracy: 0.8224 - val_loss: 0.7551 - learning_rate: 1.0000e-04
# Epoch 28/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 794s 4s/step - accuracy: 0.9121 - loss: 0.4179 - val_accuracy: 0.8089 - val_loss: 0.7795 - learning_rate: 1.0000e-04
# Epoch 29/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 793s 4s/step - accuracy: 0.9150 - loss: 0.4312 - val_accuracy: 0.8319 - val_loss: 0.7211 - learning_rate: 1.0000e-04
# Epoch 30/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 789s 4s/step - accuracy: 0.9118 - loss: 0.4148 - val_accuracy: 0.8217 - val_loss: 0.7629 - learning_rate: 1.0000e-04
# Epoch 31/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 785s 4s/step - accuracy: 0.9067 - loss: 0.4296 - val_accuracy: 0.8132 - val_loss: 0.8080 - learning_rate: 1.0000e-04
# Epoch 32/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 783s 4s/step - accuracy: 0.9055 - loss: 0.4151 - val_accuracy: 0.8178 - val_loss: 0.7752 - learning_rate: 1.0000e-04
# Epoch 33/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9134 - loss: 0.3994
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 775s 3s/step - accuracy: 0.9134 - loss: 0.3994 - val_accuracy: 0.8191 - val_loss: 0.7786 - learning_rate: 1.0000e-04
# Epoch 34/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 781s 4s/step - accuracy: 0.9154 - loss: 0.4059 - val_accuracy: 0.8191 - val_loss: 0.8020 - learning_rate: 5.0000e-05
# Epoch 35/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 783s 4s/step - accuracy: 0.9201 - loss: 0.3829 - val_accuracy: 0.8224 - val_loss: 0.7605 - learning_rate: 5.0000e-05
# Epoch 36/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 784s 4s/step - accuracy: 0.9172 - loss: 0.3997 - val_accuracy: 0.8142 - val_loss: 0.7752 - learning_rate: 5.0000e-05
# Epoch 37/50
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9086 - loss: 0.4007
# Epoch 37: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 777s 3s/step - accuracy: 0.9086 - loss: 0.4007 - val_accuracy: 0.8155 - val_loss: 0.7736 - learning_rate: 5.0000e-05
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 29.

# %% [markdown]
# # Fine-tuning

# %%
net.trainable = True
for layer in net.layers[:-20]:
    layer.trainable = False

# %% [markdown]
# # Giảm learning rate để fine-tune

# %%
adam_finetune = tf.keras.optimizers.Adam(learning_rate=1e-5)  
model.compile(optimizer=adam_finetune, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Callback cho fine-tuning

# %%
ES_finetune = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10, 
                            mode='min', restore_best_weights=True, verbose=1)
RL_finetune = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, 
                                verbose=1, mode='min', min_lr=1e-7)
callbacks_finetune = [ES_finetune, RL_finetune]

# %% [markdown]
# # Huấn luyện lần 2 (fine-tune)

# %%
history2 = model.fit(
    train_data,
    validation_data=valid_data,
    epochs=50,
    callbacks=callbacks_finetune,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    class_weight=class_weight_dict
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 6
#       1 history2 = model.fit(
#       2     train_data,
#       3     validation_data=valid_data,
#       4     epochs=50,
#       5     callbacks=callbacks_finetune,
# ----> 6     steps_per_epoch=steps_per_epoch,
#       7     validation_steps=validation_steps,
#       8     class_weight=class_weight_dict
#       9 )
#
# NameError: name 'steps_per_epoch' is not defined

# %% [markdown]
# # Hiển thị lịch sử huấn luyện

# %%
plt.plot(history1.history['accuracy'], label='Training Accuracy Phase 1')
plt.plot(history1.history['val_accuracy'], label='Validation Accuracy Phase 1')
plt.plot(history2.history['accuracy'], label='Training Accuracy Phase 2')
plt.plot(history2.history['val_accuracy'], label='Validation Accuracy Phase 2')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plt.plot(history1.history['accuracy'], label='Training Accuracy Phase 1')
#       2 plt.plot(history1.history['val_accuracy'], label='Validation Accuracy Phase 1')
#       3 plt.plot(history2.history['accuracy'], label='Training Accuracy Phase 2')
#
# NameError: name 'history1' is not defined
